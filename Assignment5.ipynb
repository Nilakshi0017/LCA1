# %%
def check_string(s):
    return s.isalnum()

# Example usage
s1 = "Hello123"
s2 = "Hello 123!"  # contains space and special character

print(check_string(s1))  # True
print(check_string(s2))  # False
# Out:
# True
# False

# %%
import re

def check_string(s):
    pattern = r"^[A-Za-z0-9]+$"  # ^ = start, $ = end, + = one or more
    return bool(re.match(pattern, s))

# Example usage
s1 = "Hello123"
s2 = "Hello_123"  # contains underscore

print(check_string(s1))  # True
print(check_string(s2))  # False
# Out:
# True
# False
